# %% [markdown]
# #Data_Science Project on Health_Care

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('/content/Patient Health Dataset.csv')
display(df)
# Out:
#       Age                                           Symptoms  \
# 0    19.0  Sudden fever, chills, cough, sore throat, runn...
# 1    25.0  I can't stop sneezing and my nose is really ru...
# 2    25.0              Red, inflamed, and itchy skin patches
# 3    25.0  Shortness of breath, wheezing, chest tightness...
# 4    25.0  Shortness of breath, wheezing, chest tightness...
# ..    ...                                                ...
# 257   NaN  I've been feeling really cold and tired lately...
# 258   NaN  I feel a sudden, severe pressure and pain in m...
# 259   NaN  A skin rash with several pus-filled pimples an...
# 260   NaN  I have pain in my abdomen, and often get fever...
# 261   NaN  I have been experiencing joint pain in my fing...
#
#                      Disease Blood Pressure  Cholestoral Level   Cough  \
# 0                  Influenza             Yes            Normal     Yes
# 1                Common Cold          Normal            Normal     Yes
# ...

# %%
df.head(5)
# Out:
#     Age                                           Symptoms      Disease  \
# 0  19.0  Sudden fever, chills, cough, sore throat, runn...    Influenza
# 1  25.0  I can't stop sneezing and my nose is really ru...  Common Cold
# 2  25.0              Red, inflamed, and itchy skin patches       Eczema
# 3  25.0  Shortness of breath, wheezing, chest tightness...       Asthma
# 4  25.0  Shortness of breath, wheezing, chest tightness...       Asthma
#
#   Blood Pressure  Cholestoral Level Cough  \
# 0             Yes            Normal   Yes
# 1          Normal            Normal   Yes
# 2          Normal            Normal    No
# 3          Normal            Normal   Yes
# 4          Normal            Normal   Yes
#
#                                          Description  \
# 0  Influenza is a contagious viral infection affe...
# 1  The common cold is a mild viral infection of t...
# 2  Eczema is a long-term skin condition causing d...
# 3  Asthma is a chronic lung condition causing air...
# ...

# %%
X = df['Disease']
y = df['Medicine']

# %%
print(X.dtypes)
print(y.unique())
# Out:
# object
# ['Oseltamivir (Tamiflu).' 'Paracetamol (Acetaminophen)'
#  'Topical corticosteroids (Hydrocortisone 1% cream)' 'Salbutamol'
#  'Methimazole' 'Cetirizine' 'Diazepam' 'Metformin' 'ORS' 'Painkillers'
#  'Methotrexate' 'Fluoxetine' 'Sorafenib' 'Alteplase' 'Nitrofurantoin'
#  'Paracetamol' 'Antiviral' 'Sunitinib' 'Sumatriptan' 'Prednisone'
#  'Amoxicillin' 'Mesalamine' 'Lithium' 'Baclofen' 'Capecitabine'
#  'Atorvastatin' 'Azithromycin' 'Amlodipine' 'Ursodeoxycholic'
#  'Chloroquine' 'Losartan' 'Isotretinoin,Adapalene' 'Temozolomide'
#  'Vaccine' 'Acyclovir' 'Isoniazid' 'Erlotinib' 'Remdesivir' 'Omeprazole'
#  ' Azithromycin' 'Zolpidem' 'Favipiravir' 'Doxycycline' ' Ceftriaxone'
#  'Zidovudine' 'Ciprofloxacin' 'Tamoxifen' 'Tenofovir' 'Levothyroxine'
#  'Lutein' 'Clotrimazole' 'Antihistamine' 'Mannitol' '\tSupportive'
#  'Sofosbuvir' '\tPeginterferon' 'Prednisolone' ' Aspirin  ']

# %%
le = LabelEncoder()
le_X = LabelEncoder()
le_y = LabelEncoder()
X_encoded = pd.get_dummies(X, drop_first=True)
y_encoded = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded,y_encoded, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
#y_pred = model.predict(X_test)
# Out:
# LinearRegression()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# Separate features (X) and target (y)
X = df[['Disease', 'Symptoms']]  # Include both Disease and Symptoms as features
y = df['Medicine']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Create a column transformer to apply one-hot encoding to both 'Disease' and 'Symptoms' columns
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot_disease', OneHotEncoder(handle_unknown='ignore'), ['Disease']),
        ('onehot_symptoms', OneHotEncoder(handle_unknown='ignore'), ['Symptoms'])
    ],
    remainder='passthrough'
)

# Create a pipeline with the preprocessor and the classifier
model = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', RandomForestClassifier(random_state=42))])

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on test set: {accuracy}")
# Out:
# Accuracy on test set: 0.8285714285714286

# %%
# Get disease and symptoms input from the user
disease_input = input("Enter the disease: ")
symptoms_input = input("Enter the symptoms: ")

# Format the input as a DataFrame
new_patient_data = pd.DataFrame({'Disease': [disease_input], 'Symptoms': [symptoms_input]})

# Predict the medicine using the trained model
predicted_medicine = model.predict(new_patient_data)

# Print the predicted medicine
print(f"For '{disease_input}' with symptoms '{symptoms_input}', the predicted medicine is: {predicted_medicine[0]}")
# Out:
# Enter the disease: fever
# Enter the symptoms: pain
# For 'fever' with symptoms 'pain', the predicted medicine is: Ursodeoxycholic
